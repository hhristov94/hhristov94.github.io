# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
fig = plt.figure(figsize=(16, 10), dpi=80)
ax = fig.gca(projection='3d')

# Make data.
X = np.arange(-2.5, 2.5, 0.025)
Y = np.arange(-2.5, 2.5, 0.025)
X, Y = np.meshgrid(X, Y)
#R = np.sqrt(X**2 + Y**2)
#Z = np.sin(R)
Z =  X * np.exp(-1 * (X**2 + Y**2))

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.inferno,
                       linewidth=0, antialiased=True)

# Customize the z axis.
ax.set_zlim(-0.5, 0.5)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel(r'$Z = xe^{-(x^2+y^2}$')

plt.show()

# %%
Z
# Out:
# array([[-9.31663293e-06, -1.04450267e-05, -1.16942654e-05, ...,
#          1.30751971e-05,  1.16942654e-05,  1.04450267e-05],
#        [-1.05505320e-05, -1.18283708e-05, -1.32430592e-05, ...,
#          1.48068821e-05,  1.32430592e-05,  1.18283708e-05],
#        [-1.19329238e-05, -1.33781925e-05, -1.49782415e-05, ...,
#          1.67469656e-05,  1.49782415e-05,  1.33781925e-05],
#        ...,
#        [-1.34795846e-05, -1.51121787e-05, -1.69196147e-05, ...,
#          1.89175882e-05,  1.69196147e-05,  1.51121787e-05],
#        [-1.19329238e-05, -1.33781925e-05, -1.49782415e-05, ...,
#          1.67469656e-05,  1.49782415e-05,  1.33781925e-05],
#        [-1.05505320e-05, -1.18283708e-05, -1.32430592e-05, ...,
#          1.48068821e-05,  1.32430592e-05,  1.18283708e-05]])

# %%
plt.figure(figsize=(12,12), dpi=80)
contours = plt.contour(X, Y, Z, 15, colors='black')

plt.clabel(contours, inline=True, fontsize=8)

plt.imshow(Z, extent=[-2,2, -2, 2], origin='lower',
           cmap='inferno', alpha=0.9)

plt.xlabel('X')
plt.ylabel('Y')
plt.grid(False)

# %%
dy, dx= np.gradient(Z)

# %%
A = np.stack([dy, dx])

# %%
N = np.apply_along_axis(np.linalg.norm, 0, A)

# %%
# Every 3rd point in each direction.
skip = (slice(None, None, 5), slice(None, None, 5))

fig = plt.figure(figsize=(12, 12), dpi=80)
ax = fig.add_subplot(111)
ax.quiver(X[skip], Y[skip], dx[skip],dy[skip],N[skip], cmap = "Reds" )
ax.set(aspect=1)
plt.show()

# %%
fig = plt.figure(figsize=(20, 12), dpi=80)
ax = fig.add_subplot(121)
contours = plt.contour(X, Y, Z, 15, colors='black')

ax.clabel(contours, inline=True, fontsize=8)

ax.imshow(Z, extent=[-2,2, -2, 2], origin='lower',
           cmap='inferno', alpha=0.9)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Contour of Z')
ax.grid(False)

ax = fig.add_subplot(122)

ax.quiver(X[skip], Y[skip], dx[skip],dy[skip],N[skip], cmap = "inferno" )
ax.imshow(Z, extent=[-2,2, -2, 2], origin='lower',
           cmap='inferno', alpha=0.9)
ax.set(aspect=1)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Gradient Field of Z')
ax.grid(False)
plt.show()

# %%
fig = plt.figure(figsize=(16, 10), dpi=80)
ax = fig.gca(projection='3d')

# Make data.
X = np.arange(-2.5, 2.5, 0.025)
Y = np.arange(-2.5, 2.5, 0.025)
X, Y = np.meshgrid(X, Y)
#R = np.sqrt(X**2 + Y**2)
#Z = np.sin(R)
Z =  X * np.exp(-1 * (X**2 + Y**2))

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.inferno,
                       linewidth=0, antialiased=True)
ax.contour(X, Y, Z, zdir='z', offset = -0.5,cmap='inferno')
# Customize the z axis.
ax.set_zlim(-0.5, 0.5)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel(r'$Z = xe^{-(x^2+y^2}$')

plt.show()
